# %% [markdown]
# <!--BOOK_INFORMATION-->
# <!--<img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">-->
#
# *[Notas de aula da disciplina de
# Modelagem Matemática](https://github.com/rmsrosa/modelagem_matematica)
# do [IM-UFRJ](https://www.im.ufrj.br).*

# %% [markdown]
# <!--NAVIGATION-->
#
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/notebooks/01.-Parte1.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br>
#
# [<- Prefácio](00.00-Prefacio.ipynb) | [Índice](Indice.ipynb) | [Referências](99.00-Referencias.ipynb) | [Destino, Jupyter! ->](01.00-Destino_Jupyter.ipynb)
#
# ---

# %% [markdown]
# # PARTE I - Aspectos Iniciais
#
# <p style="margin-bottom:20cm;"></p>

# %% [markdown]
# <!--NAVIGATION-->
#
# ---
# [<- Prefácio](00.00-Prefacio.ipynb) | [Índice](Indice.ipynb) | [Referências](99.00-Referencias.ipynb) | [Destino, Jupyter! ->](01.00-Destino_Jupyter.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/notebooks/01.-Parte1.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br>
