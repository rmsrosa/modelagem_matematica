# %% [markdown]
# <!--BOOK_INFORMATION-->
# <!--<img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">-->
#
# *[Notas de aula da disciplina de
# Modelagem Matemática](https://github.com/rmsrosa/modelagem_matematica)
# do [IM-UFRJ](https://www.im.ufrj.br).*

# %% [markdown]
# <!--NAVIGATION-->
#
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/notebooks/02.03-Formas_de_modelagens.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br>
#
# [<- Uma modesta classificação dos fenômenos](02.02-Uma_modesta_classificacao_dos_fenomenos.ipynb) | [Índice](Indice.ipynb) | [Referências](99.00-Referencias.ipynb) | [Primeiros passos na modelagem ->](03.00-Primeiros_passos_na_modelagem.ipynb)
#
# ---

# %% [markdown]
# # Formas de modelagens

# %% [markdown]
# ## Princípios:
#
# - Fundamentais
# - Empíricas
# - Heurísticas/Fenomenológicas

# %% [markdown]
# ## Abordagens:
#
# - Dimensionais
# - Analíticas
# - Geométricas
# - Numéricas
#
# ??

# %% [markdown]
# ## Técnicas:
#
# Algumas técnicas que podemos comentar:
# - Relações diretas
# - Ajustes de curvas
# - Grafos
# - Estatísticos
# - Probabilísticos
# - Equações diferenciais ordinárias
# - Equações diferenciais parcias
# - Equações estocásticas
# - Otimização

# %% [markdown]
# <!--NAVIGATION-->
#
# ---
# [<- Uma modesta classificação dos fenômenos](02.02-Uma_modesta_classificacao_dos_fenomenos.ipynb) | [Índice](Indice.ipynb) | [Referências](99.00-Referencias.ipynb) | [Primeiros passos na modelagem ->](03.00-Primeiros_passos_na_modelagem.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/notebooks/02.03-Formas_de_modelagens.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br>
