# %% [markdown]
# <!--BOOK_INFORMATION-->
# <!--<img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">-->
#
# *[Notas de aula da disciplina de
# Modelagem Matemática](https://github.com/rmsrosa/modelagem_matematica)
# do [IM-UFRJ](https://www.im.ufrj.br).*

# %% [markdown]
# <!--NAVIGATION-->
#
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/notebooks/03.02-Criterios_de_informaçao_e_a_escolha_do_modelo.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br>
#
# [<- Ajuste de dados](03.01-Ajuste_de_dados.ipynb) | [Índice](Indice.ipynb) | [Referências](99.00-Referencias.ipynb) | [Exemplos simples ->](03.03-Exemplos_simples.ipynb)
#
# ---

# %% [markdown]
# # Critérios de informação e a escolha do modelo

# %% [markdown]
# ## O critério de informação de Akaike (AIC)

# %% [markdown]
# ##  O critério de informação Bayesiano (BIC)

# %% [markdown]
# <!--NAVIGATION-->
#
# ---
# [<- Ajuste de dados](03.01-Ajuste_de_dados.ipynb) | [Índice](Indice.ipynb) | [Referências](99.00-Referencias.ipynb) | [Exemplos simples ->](03.03-Exemplos_simples.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/notebooks/03.02-Criterios_de_informaçao_e_a_escolha_do_modelo.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br>
