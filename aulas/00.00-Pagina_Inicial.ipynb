# %% [markdown]
# <!--HEADER-->
# [*Guia de aulas da disciplina de Modelagem Matemática*](https://github.com/rmsrosa/modelagem_matematica) *do* [*IM-UFRJ*](https://www.im.ufrj.br).

# %% [markdown]
# <!--NAVIGATOR-->
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/aulas/00.00-Pagina_Inicial.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# &nbsp;
# <a href="https://mybinder.org/v2/gh/rmsrosa/modelagem_matematica/master?filepath=aulas/00.00-Pagina_Inicial.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
# &nbsp;
# <a href="https://nbviewer.jupyter.org/github/rmsrosa/modelagem_matematica/blob/master/aulas/00.00-Pagina_Inicial.slides.html"><img align="left" src="https://rmsrosa.github.io/jupyterbookmaker/badges/slides_badge.svg" alt="Open slides" title="Open and View Slides"></a>
# &nbsp;
#
# | [Página Inicial](00.00-Pagina_Inicial.ipynb) | [Aula 1: Modelagem, python, jupyter, mínimos quadrados, regressão linear e ajuste de parâmetros ->](01.00-Aula1.ipynb)
#
# ---

# %% [markdown]
# # Página Inicial
#
# Este diretório contém o guia de aulas da disciplina de Modelagem Matemática do [Instituto de Matemática da UFRJ](http://www.im.ufrj.br), acompanhando as notas de aula neste mesmo repositório [rmsrosa/modelagem_matematica](https://github.com/rmsrosa/modelagem_matematica).
#
#
# O texto está disponível sob a [licença CC-BY-NC-ND](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode) e os códigos estão disponíveis sob a [licença GNU GPL Versão 3](https://www.gnu.org/licenses/gpl.html).

# %% [markdown]
# ## Sumário

# %% [markdown]
# <!--TABLE_OF_CONTENTS-->
#
# ### [Página Inicial](00.00-Pagina_Inicial.ipynb)
#
# ### [Aula 1: Modelagem, python, jupyter, mínimos quadrados, regressão linear e ajuste de parâmetros](01.00-Aula1.ipynb)
#
# ### [Aula 2: Analisando a oscilação de um pêndulo](02.00-Aula2.ipynb)
#
# ### [Aula 3: Continuação da análise do pêndulo](03.00-Aula3.ipynb)
#
# ### [Aula 4: Estimativa básica de propagação de erros experimentais](04.00-Aula4.ipynb)
#
# ### [Aula 5: Incerteza e intervalos e graus de confiança](05.00-Aula5.ipynb)
#
# ### [Aula 6: Regressão semi-linear, ajustes de ordem mais alta e critérios de seleção do ajuste](06.00-Aula6.ipynb)
#
# ### [Aula 7: Otimização e regressão não-linear](07.00-Aula7.ipynb)
#
# ### [Aula 8: O pêndulo com ângulos grandes, um pouco de EDO e simulações](08.00-Aula8.ipynb)
#
# ### [Aula 9: Pêndulo via deteção de movimento](09.00-Aula9.ipynb)
#
# ### [Aula 10: Leis de Kepler e dados da NASA](10.00-Aula10.ipynb)
#
# ### [Aula 11: Epidemiologia - tipos de modelos, o modelo SIR compartimental e o modelo SIR individual](11.00-Aula11.ipynb)
#
# ### [Aula 12: Epidemiologia - outros modelos compartimentais](12.00-Aula12.ipynb)
#
# &nbsp;&nbsp;&nbsp;&nbsp; [Projeto 3: Controle de epidemia via vacinação](12.05-Projeto3.ipynb)
#
# ### [Aula 13: Epidemiologia: o modelo SIR em rede](13.00-Aula13.ipynb)
#
# ### [Aula 14: Modelagem com Equações a Derivadas Parciais](14.00-Aula14.ipynb)
#
# ### [Aula 15: Exemplos de modelagem com EDP](15.00-Aula15.ipynb)
#
# ### [Aula 16:  Exercício em sala](16.00-Aula16.ipynb)
#
# ### [Aula 17: Séries e transformada de Fourier, algumas aplicações](17.00-Aula17.ipynb)
#
# ### [Aula 18: Transformada de Radon, suas generalizações e raio-X](18.00-Aula18.ipynb)
#
# ### [Aula 19: Inversão da transformada de Radon e recuperação de imagens](19.00-Aula19.ipynb)
#
# &nbsp;&nbsp;&nbsp;&nbsp; [Projeto 4: simulações com EDP](19.01-Projeto4.ipynb)
#
# ### [Aula 20: Retroprojeção não-filtrada](20.00-Aula20.ipynb)
#
# ### [Aula 21: Sismologia](21.00-Aula21.ipynb)

# %% [markdown]
# <!--NAVIGATOR-->
#
# ---
# | [Página Inicial](00.00-Pagina_Inicial.ipynb) | [Aula 1: Modelagem, python, jupyter, mínimos quadrados, regressão linear e ajuste de parâmetros ->](01.00-Aula1.ipynb)
#
# <a href="https://colab.research.google.com/github/rmsrosa/modelagem_matematica/blob/master/aulas/00.00-Pagina_Inicial.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
#
# <a href="https://mybinder.org/v2/gh/rmsrosa/modelagem_matematica/master?filepath=aulas/00.00-Pagina_Inicial.ipynb"><img align="left" src="https://mybinder.org/badge.svg" alt="Open in binder" title="Open and Execute in Binder"></a>
#
# <a href="https://nbviewer.jupyter.org/github/rmsrosa/modelagem_matematica/blob/master/aulas/00.00-Pagina_Inicial.slides.html"><img align="left" src="https://rmsrosa.github.io/jupyterbookmaker/badges/slides_badge.svg" alt="Open slides" title="Open and View Slides"></a>
# &nbsp;
